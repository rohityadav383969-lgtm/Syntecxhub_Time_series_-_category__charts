# %%
import matplotlib.pyplot as plt

# %%
x = [1,3,5,7,9]

# %%
y = [2,4,6,8,10]

# %%
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.plot(x,y)

# %%
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.bar(x,y)
